# %% [markdown]
# ## Data Cleaning and Exploratory Data Analysis

# %% [markdown]
# ### Importing Libraries

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Uploading Data

# %%
df = pd.read_csv('../data/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ### Data Analysis

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### Univariate Analysis

# %%
sns.set_style('whitegrid')
sns.set_palette('RdBu_r')
custom_palette = sns.color_palette('RdBu_r', n_colors=10)
colour1, colour2 = custom_palette[2], custom_palette[8]

# %% [markdown]
# ##### Target Variable (Class)

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
g = sns.countplot(data=df, x='Class')
g.set_title('Countplot of Fraudulent and Non-Fraudulent Transactions')
g.set_ylabel('Count')
g.set_xlabel('Transactions')
g.set_xticklabels(['Non-Fraudulent','Fraudulent'], fontsize=10);

# %%
g.figure.savefig('../assets/cnt_plt_classes', dpi=300, bbox_inches='tight')

# %% [markdown]
# ##### Time Since First Transaction

# %%
h = sns.histplot(data=df, x='Time', kde=True)
h.set_xlim([0,175000]);

# %%
h.figure.savefig('../assets/hist_trans_sincefirst', dpi=300, bbox_inches='tight')

# %%
fraud = df[df['Class']==1]
not_fraud = df[df['Class']==0]

# %%
k = sns.histplot(data=fraud, x='Time', kde=True, bins=40)
k.set_xlim([0,175000]);

# %%
k.figure.savefig('../assets/hist_fraud', dpi=300, bbox_inches='tight')

# %%
j = sns.histplot(data=not_fraud, x='Time', kde=True, bins=50)
j.set_xlim([0,175000]);

# %%
j.figure.savefig('../assets/hist_non_fraud', dpi=300, bbox_inches='tight')

# %% [markdown]
# ##### Amount

# %%
plt.figure(figsize=(12,12))
sns.histplot(data=df, x='Amount', hue='Class', palette=[colour1,colour2]);

# %% [markdown]
# This is difficult to read. Will try using a box plot and seperating by class because the data is imbalanced so we will not see the fraudulant transactions very well.

# %%
plt.figure(figsize=(12,4))
kk = sns.boxplot(data=df, y='Amount', x='Class', palette=[colour1,colour2])
kk.set_ylabel('Transation Amount')
kk.set_xlabel('Nature of Transaction');

# %%
plt.figure(figsize=(12,4))
k = sns.boxplot(data=fraud, x='Amount', palette=[colour2])
k.set_xlabel('Transaction Amount');

# %%
k.figure.savefig('../assets/box_fraud', dpi=300, bbox_inches='tight')

# %%
median_fraud = fraud['Amount'].median()
lower_half_fraud = fraud[fraud['Amount'] <= median_fraud]

# %%
plt.figure(figsize=(12,4))
k1 = sns.boxplot(data=lower_half_fraud, x='Amount', palette=[colour2])
k1.set_xlabel('Transaction Amount');

# %%
k1.figure.savefig('../assets/box_fraud_50', dpi=300, bbox_inches='tight')

# %%
plt.figure(figsize=(12,4))
l = sns.boxplot(data=not_fraud, x='Amount', palette=[colour1])
l.set_xlabel('Transaction Amount');

# %%
l.figure.savefig('../assets/box_non_fraud', dpi=300, bbox_inches='tight')

# %%
median_non_fraud = not_fraud['Amount'].median()
lower_half_non_fraud = not_fraud[not_fraud['Amount'] <= median_non_fraud]

# %%
plt.figure(figsize=(12,4))
l1 = sns.boxplot(data=lower_half_non_fraud, x='Amount', palette=[colour1])
l1.set_xlabel('Transaction Amount');

# %%
l1.figure.savefig('../assets/box_non_fraud_50', dpi=300, bbox_inches='tight')

# %% [markdown]
# #### Multivariate Analysis

# %%
df.corr(numeric_only=True)['Class'].sort_values(ascending=False)[1:]
# Out:
# V11       0.149067
# V4        0.129326
# V2        0.084624
# V19       0.033631
# V8        0.033068
# V21       0.026357
# V27       0.021892
# V20       0.021486
# V28       0.009682
# Amount    0.005777
# V22       0.004887
# V26       0.004265
# V25       0.003202
# V15      -0.003300
# V13      -0.003897
# V23      -0.006333
# V24      -0.007210
# Time     -0.012359
# V6       -0.043915
# V5       -0.087812
# V9       -0.094021
# V1       -0.094486
# V18      -0.105340
# V7       -0.172347
# V3       -0.182322
# V16      -0.187186
# V10      -0.206971
# V12      -0.250711
# V14      -0.293375
# V17      -0.313498
# Name: Class, dtype: float64

# %%
sns.heatmap(df.corr(numeric_only=True), cmap='RdBu_r');

# %%
corr_features = df[['V11','V4','V2','V19','Class']]
corr_features.head()
# Out:
#         V11        V4        V2       V19  Class
# 0 -0.551600  1.378155 -0.072781  0.403993      0
# 1  1.612727  0.448154  0.266151 -0.145783      0
# 2  0.624501  0.379780 -1.340163 -2.261857      0
# 3 -0.226487 -0.863291 -0.185226 -1.232622      0
# 4 -0.822843  0.403034  0.877737  0.803487      0

# %%
pp = sns.pairplot(data=corr_features, hue='Class', palette=[colour1, colour2])

pp._legend.set_title('Transaction Type')
new_labels = ['Non-Fraudulent','Fraudulent']
for text, new_label in zip(pp._legend.texts, new_labels):
    text.set_text(new_label)

pp._legend.set_bbox_to_anchor((1.05, 0.5))

pp.figure.subplots_adjust(top=0.95);

# %%
pp.figure.savefig('../assets/pairplot_most_corr_graphs.png', dpi=300, bbox_inches='tight')

# %%
neg_corr_features = df[['V10','V12','V14','V17','Class']]
neg_corr_features.head()
# Out:
#         V10       V12       V14       V17  Class
# 0  0.090794 -0.617801 -0.311169  0.207971      0
# 1 -0.166974  1.065235 -0.143772 -0.114805      0
# 2  0.207643  0.066084 -0.165946  1.109969      0
# 3 -0.054952  0.178228 -0.287924 -0.684093      0
# 4  0.753074  0.538196 -1.119670 -0.237033      0

# %%
qq = sns.pairplot(data=neg_corr_features, hue='Class', palette=[colour1, colour2])

qq._legend.set_title('Transaction Type')
new_labels = ['Non-Fraudulent','Fraudulent']
for text, new_label in zip(qq._legend.texts, new_labels):
    text.set_text(new_label)

qq._legend.set_bbox_to_anchor((1.05, 0.5))

qq.figure.subplots_adjust(top=0.95);

# %%
qq.figure.savefig('../assets/pairplot_most_neg_corr_graphs.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Saving Cleaned Data

# %%
df.to_csv('../data/Cleaned_data.csv')
